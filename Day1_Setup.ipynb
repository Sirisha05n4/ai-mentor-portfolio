# %% [markdown]
# # Day 1 — Lab 1B: Toolkit Setup
#
# This notebook demonstrates setting up the Google Gemini API client and making a Hello-Gemini call.

# %%
# !pip install -q google-genai

# %%
import os, getpass
if 'GEMINI_API_KEY' not in os.environ:
    os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# Here is the 5-Layer AI Skill Pyramid summarized in 4 short bullet points:
#
# - **Layer 1: Prompt Engineering & AI Workflows** – Mastering direct interaction with models using prompting patterns and structuring everyday tasks.
# - **Layer 2: RAG & Vector Databases** – Enhancing LLM capabilities with semantic search, external knowledge retrieval, and custom data context.
# - **Layer 3: Fine-Tuning & Custom Models** – Adapting open and closed-source models to specific domains or style requirements using specialized datasets.
# - **Layer 4 & 5: Autonomous Agents & System Orchestration** – Building multi-agent systems that plan, act, and collaborate to solve complex, end-to-end workflows.
